# %%
import pandas as pd

# %%
df = pd.read_csv('adult.data.csv')
df.head(10)
# Out:
#    age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 0   39         State-gov   77516  ...             40   United-States  <=50K
# 1   50  Self-emp-not-inc   83311  ...             13   United-States  <=50K
# 2   38           Private  215646  ...             40   United-States  <=50K
# 3   53           Private  234721  ...             40   United-States  <=50K
# 4   28           Private  338409  ...             40            Cuba  <=50K
# 5   37           Private  284582  ...             40   United-States  <=50K
# 6   49           Private  160187  ...             16         Jamaica  <=50K
# 7   52  Self-emp-not-inc  209642  ...             45   United-States   >50K
# 8   31           Private   45781  ...             50   United-States   >50K
# 9   42           Private  159449  ...             40   United-States   >50K
#
# [10 rows x 15 columns]

# %%
df.shape
# Out:
# (32561, 15)

# %%
df['race'].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
round(df[df['sex'] == 'Male']['age'].mean(), 1)
# Out:
# 39.4

# %%
round(df[df['education'] == 'Bachelors'].shape[0] / df.shape[0] * 100, 1)
# Out:
# 16.4

# %%
df2 = df[df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]
df2[df2['salary'] == '>50K']
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 8       31           Private   45781  ...             50   United-States   >50K
# 9       42           Private  159449  ...             40   United-States   >50K
# 11      30         State-gov  141297  ...             40           India   >50K
# 19      43  Self-emp-not-inc  292175  ...             45   United-States   >50K
# 20      40           Private  193524  ...             60   United-States   >50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 32533   54           Private  337992  ...             50           Japan   >50K
# 32536   34           Private  160216  ...             55   United-States   >50K
# 32538   38           Private  139180  ...             45   United-States   >50K
# 32539   71                 ?  287372  ...             10   United-States   >50K
# 32554   53           Private  321865  ...             40   United-States   >50K
#
# ...

# %%
df3 = df[~df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]
df3[df3['salary'] == '>50K']
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 7       52  Self-emp-not-inc  209642  ...             45   United-States   >50K
# 10      37           Private  280464  ...             80   United-States   >50K
# 14      40           Private  121772  ...             40               ?   >50K
# 27      54                 ?  180211  ...             60           South   >50K
# 38      31           Private   84154  ...             38               ?   >50K
# ...    ...               ...     ...  ...            ...             ...    ...
# 32518   57         Local-gov  110417  ...             40   United-States   >50K
# 32519   46           Private  364548  ...             48   United-States   >50K
# 32545   39         Local-gov  111499  ...             20   United-States   >50K
# 32557   40           Private  154374  ...             40   United-States   >50K
# 32560   52      Self-emp-inc  287927  ...             40   United-States   >50K
#
# ...

# %%
round(sum(df[df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]['salary'] == '>50K') / 
      len(df[df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]['salary'] == '>50K') * 100, 1)
# Out:
# 46.5

# %%
round(sum(df[~df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]['salary'] == '>50K') /
 len(df[~df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]['salary'] == '>50K') * 100, 1)
# Out:
# 17.4

# %%
round(sum(df[~df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]['salary'] == '>50K') / df.shape[0] * 100, 1)
# Out:
# 13.4

# %%
df['hours-per-week'].min()
# Out:
# 1

# %%
df[df['hours-per-week'] == df['hours-per-week'].min()]
# Out:
#        age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 189     58         State-gov  109567  ...              1   United-States   >50K
# 1036    66      Self-emp-inc  150726  ...              1               ?  <=50K
# 1262    69                 ?  195779  ...              1   United-States  <=50K
# 5590    78                 ?  363134  ...              1   United-States  <=50K
# 5632    45                 ?  189564  ...              1   United-States  <=50K
# 5766    62                 ?   97231  ...              1   United-States  <=50K
# 5808    76                 ?  211574  ...              1   United-States  <=50K
# 8447    67                 ?  244122  ...              1   United-States  <=50K
# 9147    75                 ?  260543  ...              1           China  <=50K
# 11451   27           Private  147951  ...              1   United-States  <=50K
# 19337   72                 ?   76860  ...              1   United-States  <=50K
# ...

# %%
round(sum(df[df['hours-per-week'] == df['hours-per-week'].min()]['salary'] == '>50K') / 
      len(df[df['hours-per-week'] == df['hours-per-week'].min()]['salary'] == '>50K') * 100, 1)
# Out:
# 10.0

# %%
s = df[df['salary'] == '>50K']['native-country'].value_counts() / df['native-country'].value_counts()
s.sort_values(ascending=False).index[0]
# Out:
# 'Iran'

# %%
round(max(df[df['salary'] == '>50K']['native-country'].value_counts() / df['native-country'].value_counts()) * 100, 1)
# Out:
# 41.9

# %%
df4 = df[df['salary'] == '>50K']
df4[df4['native-country'] == 'India']['occupation'].value_counts().index[0]
# Out:
# 'Prof-specialty'

# %%
# How many of each race are represented in this dataset? This should be a Pandas series with race names as the index labels.
    race_count = df['race'].value_counts()

    # What is the average age of men?
    average_age_men = round(df[df['sex'] == 'Male']['age'].mean(), 1)

    # What is the percentage of people who have a Bachelor's degree?
    percentage_bachelors = round(df[df['education'] == 'Bachelors'].shape[0] / df.shape[0] * 100, 1)

    # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
    # What percentage of people without advanced education make more than 50K?

    # with and without `Bachelors`, `Masters`, or `Doctorate`
    df2 = df[df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]
    df3 = df[~df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]

    higher_education = df2[df2['salary'] == '>50K']
    lower_education = df3[df3['salary'] == '>50K']

    # percentage with salary >50K
    higher_education_rich = round(sum(df[df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]['salary'] == '>50K') / len(df[df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]['salary'] == '>50K') * 100, 1)
    lower_education_rich = round(sum(df[~df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]['salary'] == '>50K') / len(df[~df['education'].str.match('(Bachelors)|(Masters)|(Doctorate)')]['salary'] == '>50K') * 100, 1)

    # What is the minimum number of hours a person works per week (hours-per-week feature)?
    min_work_hours = df['hours-per-week'].min()

    # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
    num_min_workers = df[df['hours-per-week'] == df['hours-per-week'].min()]

    rich_percentage = round(sum(df[df['hours-per-week'] == df['hours-per-week'].min()]['salary'] == '>50K') / len(df[df['hours-per-week'] == df['hours-per-week'].min()]['salary'] == '>50K') * 100, 1)

    # What country has the highest percentage of people that earn >50K?
    s = df[df['salary'] == '>50K']['native-country'].value_counts() / df['native-country'].value_counts()

    highest_earning_country = s.sort_values(ascending=False).index[0]
    highest_earning_country_percentage = round(max(df[df['salary'] == '>50K']['native-country'].value_counts() / df['native-country'].value_counts()) * 100, 1)

    # Identify the most popular occupation for those who earn >50K in India.
    df4 = df[df['salary'] == '>50K']

    top_IN_occupation = df4[df4['native-country'] == 'India']['occupation'].value_counts().index[0]
